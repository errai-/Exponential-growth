// %%
TFile tf("output-DATA-2b.root");
tf.cd();
tf.ls();
tf.cd("Standard");
gDirectory->cd("Eta_0.0-1.3");
gDirectory->ls();
// Out:
// TFile**		output-DATA-2b.root
//  TFile*		output-DATA-2b.root
//   KEY: TDirectoryFile	Standard;1	Standard
//   KEY: TDirectoryFile	FullEta_Reco;1	FullEta_Reco
//   KEY: TDirectoryFile	infodir;1	infodir
// TDirectoryFile*		Eta_0.0-1.3	Eta_0.0-1.3
//  KEY: TH1D	hpt;1
//  KEY: TH1D	hpt_pre;1
//  KEY: TH1D	hpt_evt;1
//  KEY: TH1D	hpt_evtcount;1
//  KEY: TH1D	hpt_jet;1
//  KEY: TH1D	hpt0;1
//  KEY: TH1D	hpt1;1
//  KEY: TH1D	hpt2;1
//  KEY: TH1D	hpt3;1
//  KEY: TH1D	hpt_noid;1
//  KEY: TH1D	hpt_noevtid;1
//  KEY: TH1D	hpt_nojetid;1
//  KEY: TProfile	pa;1
//  KEY: TProfile	pnpv;1
//  KEY: TProfile	pnpvall;1
//  KEY: TProfile	prho;1
//  KEY: TProfile	pmpf;1
//  KEY: TProfile	pmpf1;1
//  KEY: TProfile	pmpf2;1
//  KEY: TProfile	pmpfx;1
//  KEY: TProfile	pmpfy;1
//  KEY: TProfile	pmpfz;1
//  KEY: TProfile	punc;1
//  KEY: TProfile	pncand;1
//  KEY: TProfile	pnch;1
//  KEY: TProfile	pnne;1
//  KEY: TProfile	pnnh;1
//  KEY: TProfile	pnce;1
//  KEY: TProfile	pnmu;1
//  KEY: TProfile	pchf;1
// ...

// %%
TCanvas c1("test","test",800,1200);
hpt->Draw();
c1.Draw();
